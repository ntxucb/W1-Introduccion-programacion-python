# %% [markdown]
# <a href="https://colab.research.google.com/github/ntxucb/W1-Introduccion-programacion-python/blob/main/W1_D2_Intro_Python_NTXUCB_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2022-04-21 at 6.32.01 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Primera Parte. Repaso**

# %% [markdown]
# **Variable**. Una variable es donde se guarda (y se recupera) datos que se utilizan en un programa.
#
# **Tipos de datos**.
# - Enteros(int)
# - Numero en Coma Flotante(float)
# - Booleanos(bool)
# - Cadena de Caracteres(string)

# %%
edad = 20
nombre = "Carlos"
altura = 1.70
fuma = False

# %%
print(type(edad))
print(type(nombre))
print(type(altura))
print(type(fuma))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# **Reglas para nombrar variables:**

# %%
#no usar numeros por delante
24324variable = 5
# Out:
#   File "<ipython-input-24-7cc4d81247f5>", line 1
#     24324variable
#                 ^
# SyntaxError: invalid syntax

# %%
#no usar numeros extraños
$variable = 5
# Out:
#   File "<ipython-input-1-ad62c1921c37>", line 2
#     $variable = 5
#     ^
# SyntaxError: invalid syntax

# %%
#se puede usar barra baja, pero se debe evitar usar doble ya que cuando se define __ son valores que le pertenecen al sistema
_variable = 5

# %%
#Las mayusculas y minusculas no son intercambiables
Edad = 6
edad = 4
EDAD = 7
print(Edad)
print(edad)
print(EDAD)
# Out:
# 6
# 4
# 7

# %%
#Se puede usar barra baja para separar palabras y una mejor comprension
mi_variable = 5
mivariable = 5

# %% [markdown]
# **Qué es un algoritmo?**

# %% [markdown]
# Un algoritmo no es mas que una serie de instrucciones para lograr algo, al contrario de lo que mayormente se cree no es algo propio de programación ya que nuestro día a día esta lleno de algoritmos.
#
# Por ejemplo algo tan simple como hacer una taza de té sería:
# ```
# 1.   Hervir el agua
# 2.   Colocar la bolsita de té en el agua
# 3.   Vertir el agua caliente en la taza
# 4.   Esperar 3 minutos
#
# ```
#
# Esto sería un algoritmo

# %% [markdown]
# ### **Segunda Parte. Diagramas de flujo**

# %% [markdown]
# Un diagrama de flujo es una forma visual de representar un algoritmo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Como ingresar datos desde teclado?**<br>
# Podemos hacerlo usando:<br>
# `input( "Texto que se mostrara" ) `

# %%
nombre = input("Ingresa tu nombre: ")
print("Hola",nombre)
# Out:
# Ingresa tu nombre: Karen
# Hola Karen

# %%
#input siempre devolvera un valor string
print(type(nombre))
# Out:
# <class 'str'>

# %%
numero = input("Ingresa un numero: ")
suma = numero + 4
suma
# Out:
# Ingresa un numero: 56
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1ca66aaa678b> in <module>()
#       1 numero = input("Ingresa un numero: ")
# ----> 2 suma = numero + 4
#       3 suma
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Si quiero convertir un string a otro tipo de variable, puedo usar float(), int(), bool()
numero = int(input("Ingresa un numero: "))
suma = numero + 4
suma
# Out:
# Ingresa un numero: 6879
# 6883

# %%
print(type(numero))
# Out:
# <class 'int'>

# %%
variable_int = "45"
variable_bool = "True"
#imprimiendo el tipo de variable
print(type(variable_int))
print(type(variable_bool))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(variable_int+7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-53e09e2ea06c> in <module>()
# ----> 1 print(variable_int+7)
#
# TypeError: can only concatenate str (not "int") to str

# %%
var = 8
print(var)

var = 17
print(var)
# Out:
# 8
# 17

# %%
#Actualizamos el valor de las variables y ahora podemos operar con ellas
variable_int = int(variable_int)
variable_bool = bool(variable_bool)
print(type(variable_int))
print(type(variable_bool))
# Out:
# <class 'int'>
# <class 'bool'>

# %%
print(variable_int+7)
# Out:
# 52

# %% [markdown]
# **Convirtiendo el Diagrama de Flujo a Codigo:**<br>
# Instrucción: "Obtener dos números y sumarlos"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Ingresamos los numeros por teclado 
num1 = int(input("Escribe el primer número: "))
num2 = int(input("Escribe el segundo número: "))

#realizamos la suma
suma = num1 + num2
print("El resultado de la suma es:",suma)
# Out:
# Escribe el primer número: 10
# Escribe el segundo número: 3
# El resultado de la suma es: 13

# %% [markdown]
# **Ejemplo 2**
#
# Instrucción: "Escribir un programa que solicite al usuario ingresar tres números, para luego mostrarle el promedio de los tres."

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Ingresamos los numeros
num1 = int(input("Escribe el primer número: "))
num2 = int(input("Escribe el segundo número: "))
num3 = int(input("Escribe el tercer número: "))

#Sumando los numeros
suma = num1 + num2 + num3

#prom es la variable promedio
prom = suma / 3

print("El promedio es:",prom)
# Out:
# Escribe el primer número: 56
# Escribe el segundo número: 34
# Escribe el tercer número: 23
# El promedio es: 37.666666666666664

# %% [markdown]
# **Ejercicio:**<br>
# Instruccion:
# "Pedirle al usuario que ingrese dos números y sacar la multiplicación

# %% [markdown]
# ### **Tercera Parte. Condicionales**

# %% [markdown]
# Los condicionales if-else, son una estructura de control, que nos permiten tomar cierta decisión al interior de nuestro algoritmo, es decir, nos permiten determinar que acciones se realizarán o no, esto dada cierta condición.

# %% [markdown]
# ![condicional-si.png](data:image/png;base64,...)

# %% [markdown]
#  **OPERADORES RELACIONALES**
# Son utilizados para comparar valores, retornan un valor booleano

# %%
# >  <  ==  >=  <=  !=
print(5 > 6)
print(10 > 1)
# Out:
# False
# True

# %%
print(3 < 3)
print(3 <= 3)
# Out:
# False
# True

# %%
print(7 == 7)
print(8 != 8)
# Out:
# True
# False

# %%
print("Hola" == "Hola")
print("Hola" == "Ho")
# Out:
# True
# False

# %% [markdown]
# **Ejemplo**<br>
# Instrucción: "Leer un número entero y determinar si es negativo"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Ingresamos el numero y lo convertimos a entero
num1 = int(input("Escribe el número: "))

#Preguntamos si es negativo osea si es menor a cero 
if num1 < 0:
  # > < == !=
  print("El número es negativo")
else:
  print("El numero no es negativo")
# Out:
# Escribe el número: -1
# El número es negativo

# %% [markdown]
# **Indentacion:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Ejemplo:**<br>
# Instruccion: "Preguntar si una persona es mayor de edad"

# %%
#Ingresamos el numero y lo convertimos a entero
num1 = int(input("Escribe la edad: "))

#Preguntamos si es negativo osea si es menor a cero 
if num1 < 18:
  # > < == !=
  print("La persona es menor de edad")
else:
  print("La persona es mayor de edad")
# Out:
# Escribe la edad: 12
# La persona es menor de edad

# %% [markdown]
# **Operadores lógicos:**<br>
# - **Operador and <br>**
# El operador and evalúa si el valor del lado izquierdo y el lado derecho se cumplen.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
b = 7
if b > 2 and b < 4:
  print("El numero esta dentro del rango")
else:
  print("El numero esta fuera del rango")
# Out:
# El numero esta fuera del rango

# %%
b = 3
if b > 2 and b < 4:
  print("El numero esta dentro del rango")
else:
  print("El numero esta fuera del rango")
# Out:
# El numero esta dentro del rango

# %%
edad = int(input("Ingrese tu edad "))
if edad > 17 and edad < 60:
  print("Si puede obtener una licencia")
else:
  print("No puedes obtener una licencia")
# Out:
# Ingrese tu edad 22
# Si puede obtener una licencia

# %% [markdown]
# - **Operador or**<br>
# El operador or evalúa si el valor del lado izquierdo o el lado derecho se cumple

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 3
b = 4
if a == 3 or b == 7:
  print("Entramos al if")
else:
  print("Entramos al else")
# Out:
# Entramos al if

# %%
a = 3
b = 4
if a > 3 or b == 7:
  print("Entramos al if")
else:
  print("Entramos al else")
# Out:
# Entramos al else

# %%
edad = int(input("Ingrese tu edad "))
if edad != 18 or edad == 60:
  print("Entre el if")
else:
  print("Entrar al else")
# Out:
# Ingrese tu edad 18
# Entrar al else

# %% [markdown]
# Cuando se anidan varios niveles de enunciados if/else, puede ser dificil determinar cuales expresiones logicas deben ser verdaderas o falsas.
# Elif podría traducirse como Else If y se utiliza para enlazar varios else if sin aumentar las tabulaciones, vendría a ser como un “si es”

# %%
edad = int(input("Digite la edad: "))
#Condicional elif 
if edad<16:
  print("Aun no puede conducir")
else:
  if edad<18:
    print("Puede obtener un permiso para conducir")
  else:
    if edad<70:
      print("Puede obtener una licencia estandar")
    else:
      print("Requiere una licencia especial")
# Out:
# Digite la edad: 88
# Requiere una licencia especial

# %%
edad = int(input("Digite la edad: "))
#Condicional elif 
if edad<16:
  print("Aun no puede conducir")
elif edad<18:
  print("Puede obtener un permiso para conducir")
elif edad<70:
  print("Puede obtener una licencia estandar")
else:
  print("Requiere una licencia especial")
# Out:
# Digite la edad: 78
# Requiere una licencia especial

# %% [markdown]
# ### **Cuarta Parte. Ejercicios**

# %% [markdown]
# Hacer el diagrama de flujo de cada ejercicio y convertirlo a código Python.
#
# **Instruccion 1:**<br>
# Solicitar al usuario que ingrese dos números y mostrar cuál de los dos es menor. No considerar el caso en que ambos números son iguales.
#
# **Intrucción 2. Que vacuna le toca al usuario?**<br>
# Ingrese la edad de la persona, si es mayor a 4 años y menor a 17 años indicarle que le toca Pfizer, si es mayor indicarle que vacunas se puede colocar, y si es menor a 4 años indicarle que no es recomendable vacunarse
#
# **Instrucción 3. Qué tipo de psicologo necesitas?**<br>
# Los ámbitos de la psicología aplicada son muchos, y, por tanto, los psicólogos realizan distintas tareas y funciones, y trabajan con diferentes clientes: familias, organizaciones, deportistas, entre otros.
#
# Instrucción: Escribe un programa que le pida al usuario que escoja una opción
#
# Para que necesitas un psicologo?
# 1.   Quiero que evalue mi depresión
# 2.   Quiero que me ayude con mi relación de pareja
# 3.   Quiero que me ayude con mi rendimiento deportivo
#
# El programa deberá recibir el código, por ejemplo: el usuario ingresa 1 y el programa deberá imprimir que el usuario necesita un Psicologo clínico porque... y así en los tres casos.
