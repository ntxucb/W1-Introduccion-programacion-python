# %% [markdown]
# <a href="https://colab.research.google.com/github/ntxucb/W1-Introduccion-programacion-python/blob/main/W1_D1_Intro_Python_NTXUCB_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción a Python para Neurociencia

# %% [markdown]
# ![banner_logo.png](data:image/png;base64,...)

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Workshop
#
#
#
# ```
# print(2 + 2)
#
# ```
#
#
# 1.   Punto a
# 2.   Punto b
#
# ---
#
#
# ---

# %% [markdown]
# ## Workshop Python

# %%
#Esto es un comentario, no tienen ninguna influencia en el código.
#print()

# %%
1 + 2
# Out:
# 3

# %%
50000 ** 3
# Out:
# 125000000000000

# %%
print("El resultado es 3 positivo")
# Out:
# El resultado es 3 positivo

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
print(8 * 2) 

print(9 * 10)
# Out:
# 16
# 90

# %%
9 * 8
# Out:
# 72

# %%
print("Hola NeuroTechUCB")
# Out:
# Hola NeuroTechUCB

# %% [markdown]
# Ejercicio.
# Dividir su edad actual en 2.

# %% [markdown]
# #Operadores
#
# ```
# 2 + 2 #suma
# 4 - 8 #resta
# 5 * 6 #multiplicacion
# 4 / 9 #division
# 6 % 3 #modulo, el residuo de la division
# 8 ** 2 #exponencial
# ```

# %% [markdown]
# # Variables

# %% [markdown]
# #Data types (primitives)
# `7 `: es de tipo [int] #numeros enteros<br>
#
# ---
#
#
# `4.32` : es de tipo [float] #numeros flotantes (decimales)<br>
#
# ---
#
#
# `"Hello World"`: es de tipo  [string] texto<br>
#
# ---
#
#
# `True - False`: son de tipo [bool] Booleanos (verdadero o falso)<br>
#
# ---
#
#
#
#
# Comentarios largos:
# ```
# """
# fdafdsa
# asfas
# asf
# asdf
# asdf
# """
# ```
#
#
# ```
# # Tiene formato de código
# ```

# %%
"""
ju ad 
dfjs
dfksk

"""

# %%
# 1 solo =, significa asignación
nombre = "Manuel"

# %%
print(nombre)
# Out:
# Manuel

# %%
#variables

#usando datos personales
nombre = "Manuel" #string
edad = 28.0 # int
profesion = "Cientifico de datos"
sexo = "Masculino"
despierto = False

# %%
print(sexo)
# Out:
# Masculino

# %%
# Type() devolver el tipo de variable

type(edad)
# Out:
# float

# %%
type(nombre)
# Out:
# str

# %%
b = 2.0

# %% [markdown]
# #Reglas para nombrar variables <br>
# No utilizar numeros por delante <br>
# No utilizar simbolos extraños (!, @, /*-+, %) <br>
# Si se puede utilizar barra baja _ , pero se debe evitar usar dobles __ <br>
# Las mayusculas y minusculas NO son intercambiables (`Mi_Variable, mi_variable`)
# Usar nombres claros, en vez de abreviaciones (`hora_actual en vez de h_a`) <br>
# Python utiliza una convención para nombras variables usando barra baja para <br>
# separar palabras (`esta_es_mi_variable, estaesmivariable`) <br>
# Los nombres no deben exceder 20 caracteres, cada linea tiene 80 caracteres <br>

# %%
nombre = "M"

# %%
#reglas para nombrar variables
temperatura_hoy = 10
temperatura_ayer = 16

# %%
print(temperatura_hoy)
# Out:
# 10

# %% [markdown]
# #Condicionales nos permiten hacer comparaciones entre valores
# `a == b` # a es igual a b <br>
# `a != b` # a No es igual a b<br>
# `a <= b `# a es menor o igual a b<br>
# `a >= b` # a es Mayor o igual a b<br>

# %%
# Escribir un programa para determinar si la temperatura de hoy 
#es igual o menor a la de ayer
temperatura_hoy = 10.0
temperatura_ayer = 14.0
temperatura_hoy <= temperatura_ayer # la temp de hoy es menor o igual que ayer
# Out:
# True

# %%
#Escribir un programa para determinar si una persona tiene la edad minima para 
#obtener una licencia de conducir
edad_actual = 15
edad_minima = 18

# %%
entrada = edad_actual >= edad_minima
print(entrada)
# Out:
# False
